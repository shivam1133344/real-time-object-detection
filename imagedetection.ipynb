# %%
import cv2 
import matplotlib.pyplot as plt
from  ultralytics  import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\DELL\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 800.2KB/s 8.0s7.9s<0.0ss0ss

# %%
image= cv2.imread("download.jpeg")

# %%
result=model(image)
# Out:
# 0: 448x640 40 cars, 6 buss, 169.0ms
# Speed: 28.5ms preprocess, 169.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
annotated_frame=result[0].plot(font_size=0.5,
    line_width=1)

# %%
plt.imshow(cv2.cvtColor(annotated_frame , cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
